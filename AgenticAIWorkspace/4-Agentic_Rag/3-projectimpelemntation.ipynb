# %% [markdown]
# ### Agentic RAG

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
urls=[
    "https://langchain-ai.github.io/langgraph/tutorials/introduction/",
    "https://langchain-ai.github.io/langgraph/tutorials/workflows/",
    "https://langchain-ai.github.io/langgraph/how-tos/map-reduce/"
]


docs=[WebBaseLoader(url).load() for url in urls]
docs
# Out:
# [[Document(metadata={'source': 'https://langchain-ai.github.io/langgraph/tutorials/introduction/', 'title': 'Redirecting...', 'language': 'en'}, page_content='\n\n\n\nRedirecting...\n\n\n\n\n\n\nRedirecting...\n\n\n')],
#  [Document(metadata={'source': 'https://langchain-ai.github.io/langgraph/tutorials/workflows/', 'title': 'Redirecting...', 'language': 'en'}, page_content='\n\n\n\nRedirecting...\n\n\n\n\n\n\nRedirecting...\n\n\n')],
#  [Document(metadata={'source': 'https://langchain-ai.github.io/langgraph/how-tos/map-reduce/', 'title': 'Redirecting...', 'language': 'en'}, page_content='\n\n\n\nRedirecting...\n\n\n\n\n\n\nRedirecting...\n\n\n')]]

# %%
doc_list=[item for sublist in docs for item in sublist]

docs_list = [item for sublist in docs for item in sublist]

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=100
)

doc_splits = text_splitter.split_documents(docs_list)

## Add alll these text to vectordb

vectorstore=FAISS.from_documents(
    documents=doc_splits,
    embedding=HuggingFaceEmbeddings(
    model="sentence-transformers/all-MiniLM-L6-v2"
)
)


retriever=vectorstore.as_retriever()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2041.71it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
retriever.invoke("what is langgraph")
# Out:
# [Document(id='4a7a5541-824d-476e-95f5-c36a483f95fe', metadata={'source': 'https://langchain-ai.github.io/langgraph/tutorials/introduction/', 'title': 'Redirecting...', 'language': 'en'}, page_content='Redirecting...\n\n\n\n\n\n\nRedirecting...'),
#  Document(id='89815d3d-9e2a-448e-82cd-6ba579855b53', metadata={'source': 'https://langchain-ai.github.io/langgraph/tutorials/workflows/', 'title': 'Redirecting...', 'language': 'en'}, page_content='Redirecting...\n\n\n\n\n\n\nRedirecting...'),
#  Document(id='951f3abe-7391-4092-9023-b7567e98193c', metadata={'source': 'https://langchain-ai.github.io/langgraph/how-tos/map-reduce/', 'title': 'Redirecting...', 'language': 'en'}, page_content='Redirecting...\n\n\n\n\n\n\nRedirecting...')]

# %%
### Retriever To Retriever Tools
from langchain_core.tools import create_retriever_tool
retriever_tool=create_retriever_tool(
    retriever,
    "retriever_vector_db_blog",
    "Search and run information about Langgraph"
)

# %%
retriever_tool
# Out:
# StructuredTool(name='retriever_vector_db_blog', description='Search and run information about Langgraph', args_schema=<class 'langchain_core.tools.retriever.RetrieverInput'>, func=<function create_retriever_tool.<locals>.func at 0x000001AA8F025EE0>, coroutine=<function create_retriever_tool.<locals>.afunc at 0x000001AA8F0260C0>)

# %% [markdown]
# ### Langchain Blogs- Seperate Vector Store

# %%
langchain_urls=[
    "https://python.langchain.com/docs/tutorials/",
    "https://python.langchain.com/docs/tutorials/chatbot/",
    "https://python.langchain.com/docs/tutorials/qa_chat_history/"
]


docs=[WebBaseLoader(url).load() for url in urls]
docs
# Out:
# [[Document(metadata={'source': 'https://langchain-ai.github.io/langgraph/tutorials/introduction/', 'title': 'Redirecting...', 'language': 'en'}, page_content='\n\n\n\nRedirecting...\n\n\n\n\n\n\nRedirecting...\n\n\n')],
#  [Document(metadata={'source': 'https://langchain-ai.github.io/langgraph/tutorials/workflows/', 'title': 'Redirecting...', 'language': 'en'}, page_content='\n\n\n\nRedirecting...\n\n\n\n\n\n\nRedirecting...\n\n\n')],
#  [Document(metadata={'source': 'https://langchain-ai.github.io/langgraph/how-tos/map-reduce/', 'title': 'Redirecting...', 'language': 'en'}, page_content='\n\n\n\nRedirecting...\n\n\n\n\n\n\nRedirecting...\n\n\n')]]

# %%
doc_list=[item for sublist in docs for item in sublist]

docs_list = [item for sublist in docs for item in sublist]

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=100
)

doc_splits = text_splitter.split_documents(docs_list)

## Add alll these text to vectordb

vectorstorelangchain=FAISS.from_documents(
    documents=doc_splits,
    embedding=HuggingFaceEmbeddings(
    model="sentence-transformers/all-MiniLM-L6-v2"
)
)


retriever_langchain=vectorstorelangchain.as_retriever()
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3175.63it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
### Retriever To Retriever Tools
from langchain_core.tools import create_retriever_tool

retriever_tool_langchain=create_retriever_tool(
    retriever_langchain,
    "retriever_vector_langchain_blog",
    "Search and run information about Langchain"
)

# %%
tools=[retriever_tool,retriever_tool_langchain]

# %% [markdown]
# ### LangGraph Workflow
#
# Steps :
# 1. Create Seperrate Vector DB
# 2. Create tools to bind those DBS
# 3. Create State
# 4. Get LLm chat model
# 5. define Agent Node

# %%
from typing import Annotated, Sequence
from typing_extensions import TypedDict

from langchain_core.messages import BaseMessage

from langgraph.graph.message import add_messages # Reducers


class AgentState(TypedDict):
    # The add_messages function defines how an update should be processed
    # Default is to replace. add_messages says "append"
    messages: Annotated[Sequence[BaseMessage], add_messages]

# %%
from langchain_groq import ChatGroq

llm=ChatGroq(model="openai/gpt-oss-120b")
llm.invoke("Hi")
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={'reasoning_content': 'The user just says "Hi". We should respond politely. No special instructions. Use friendly greeting.'}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 72, 'total_tokens': 111, 'completion_time': 0.084932099, 'completion_tokens_details': {'reasoning_tokens': 21}, 'prompt_time': 0.013291562, 'prompt_tokens_details': None, 'queue_time': 0.060190827, 'total_time': 0.098223661}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_a09bde29de', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019db66a-d880-7081-9053-af6dc92b9fe0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 39, 'total_tokens': 111, 'output_token_details': {'reasoning': 21}})

# %%
def agent(state):
    """
    Invokes the agent model to generate a response based on the current state. Given
    the question, it will decide to retrieve using the retriever tool, or simply end.

    Args:
        state (messages): The current state

    Returns:
        dict: The updated state with the agent response appended to messages
    """
    print("---CALL AGENT---")
    messages = state["messages"]
    model = ChatGroq(model="openai/gpt-oss-120b")
    model = model.bind_tools(tools)
    response = model.invoke(messages)
    # We return a list, because this will get added to the existing list
    return {"messages": [response]}

# %%
from typing import Annotated, Literal, Sequence
from typing_extensions import TypedDict

#from langchain import hub
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

from pydantic import BaseModel, Field

# %%
### Edges
def grade_documents(state) -> Literal["generate", "rewrite"]:
    """
    Determines whether the retrieved documents are relevant to the question.

    Args:
        state (messages): The current state

    Returns:
        str: A decision for whether the documents are relevant or not
    """

    print("---CHECK RELEVANCE---")

    # Data model
    class grade(BaseModel):
        """Binary score for relevance check."""

        binary_score: str = Field(description="Relevance score 'yes' or 'no'")

    # LLM
    model = ChatGroq(model="openai/gpt-oss-120b")

    # LLM with tool and validation
    llm_with_tool = model.with_structured_output(grade)

    # Prompt
    prompt = PromptTemplate(
        template="""You are a grader assessing relevance of a retrieved document to a user question. \n 
        Here is the retrieved document: \n\n {context} \n\n
        Here is the user question: {question} \n
        If the document contains keyword(s) or semantic meaning related to the user question, grade it as relevant. \n
        Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question.""",
        input_variables=["context", "question"],
    )

    # Chain
    chain = prompt | llm_with_tool

    messages = state["messages"]
    last_message = messages[-1]

    question = messages[0].content
    docs = last_message.content

    scored_result = chain.invoke({"question": question, "context": docs})

    score = scored_result.binary_score

    if score == "yes":
        print("---DECISION: DOCS RELEVANT---")
        return "generate"

    else:
        print("---DECISION: DOCS NOT RELEVANT---")
        print(score)
        return "rewrite"

# %%
def generate(state):
    """
    Generate answer

    Args:
        state (messages): The current state

    Returns:
         dict: The updated message
    """
    print("---GENERATE---")
    messages = state["messages"]
    question = messages[0].content
    last_message = messages[-1]

    docs = last_message.content

    # Prompt
    prompt = hub.pull("rlm/rag-prompt")

    # LLM
    llm = ChatGroq(model="openai/gpt-oss-120b")

    # Post-processing
    def format_docs(docs):
        return "\n\n".join(doc.page_content for doc in docs)

    # Chain
    rag_chain = prompt | llm | StrOutputParser()

    # Run
    response = rag_chain.invoke({"context": docs, "question": question})
    return {"messages": [response]}

# %%
def rewrite(state):
    """
    Transform the query to produce a better question.

    Args:
        state (messages): The current state

    Returns:
        dict: The updated state with re-phrased question
    """

    print("---TRANSFORM QUERY---")
    messages = state["messages"]
    question = messages[0].content

    msg = [
        HumanMessage(
            content=f""" \n 
    Look at the input and try to reason about the underlying semantic intent / meaning. \n 
    Here is the initial question:
    \n ------- \n
    {question} 
    \n ------- \n
    Formulate an improved question: """,
        )
    ]

    # Grader
    model = ChatGroq(model="openai/gpt-oss-120b")
    response = model.invoke(msg)
    return {"messages": [response]}

# %%
from langgraph.graph import END, StateGraph, START
from langgraph.prebuilt import ToolNode
from langgraph.prebuilt import tools_condition

# Define a new graph
workflow = StateGraph(AgentState)

# Define the nodes we will cycle between
workflow.add_node("agent", agent)  # agent
retrieve = ToolNode([retriever_tool,retriever_tool_langchain])
workflow.add_node("retrieve", retrieve)  # retrieval
workflow.add_node("rewrite", rewrite)  # Re-writing the question
workflow.add_node(
    "generate", generate
)  # Generating a response after we know the documents are relevant
# Call agent node to decide to retrieve or not
workflow.add_edge(START, "agent")

# Decide whether to retrieve
workflow.add_conditional_edges(
    "agent",
    # Assess agent decision
    tools_condition,
    {
        # Translate the condition outputs to nodes in our graph
        "tools": "retrieve",
        END: END,
    },
)

# Edges taken after the `action` node is called.
workflow.add_conditional_edges(
    "retrieve",
    # Assess agent decision
    grade_documents,
)
workflow.add_edge("generate", END)
workflow.add_edge("rewrite", "agent")

# Compile
graph = workflow.compile()
from IPython.display import Image, display
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %%
graph.invoke({"messages":"What is Langgraph?"})
# Out:
# ---CALL AGENT---
# {'messages': [HumanMessage(content='What is Langgraph?', additional_kwargs={}, response_metadata={}, id='6bf08cf2-7097-4b27-ba45-0b917ad61b59'),
#   AIMessage(content='**LangGraph – A quick‑look**\n\nLangGraph is an open‑source Python library (maintained by the same team that builds **LangChain**) that makes it easy to turn **LLM‑driven logic into explicit, state‑ful, graph‑structured workflows**.  \nThink of it as a “workflow engine” built on top of LangChain’s primitives (chains, agents, tools, prompts, etc.) that lets you:\n\n| Feature | What it means for you |\n|---------|-----------------------|\n| **Nodes = LangChain components** | Any `Chain`, `Agent`, `Tool`, custom function, or even a raw LLM call can be a node in the graph. |\n| **Explicit state** | A single mutable `State` dictionary is passed from node to node, making it easy to read/write intermediate results, branch on conditions, and persist progress. |\n| **Directed graph topology** | Nodes are connected with edges that can be **conditional** (`if state["x"] > 0: go to node B`) or **parallel** (`run C and D concurrently`). |\n| **Built‑in loop & retry logic** | You can declare “repeat until” or “retry up to N times” without writing boilerplate. |\n| **Persistence & checkpointing** | The state can be serialized (JSON, DB, Redis, etc.) so a long‑running workflow can be stopped and resumed later. |\n| **Observability** | Integrated tracing (via LangChain’s `CallbackManager`) gives you step‑by‑step logs, token usage, and error details. |\n| **Composable & reusable** | Graphs are first‑class Python objects; you can nest graphs inside other graphs, share sub‑graphs across projects, or export them as JSON/YAML for non‑Python runtimes. |\n| **Deployment‑ready** | Works locally, in serverless functions, or on orchestration platforms (Docker, Kubernetes, LangServe, etc.). |\n\n---\n\n## 1. Core Concepts\n\n### a. `State`\nA mutable dictionary (or any pydantic model) that lives for the entire execution of the graph.  \n```python\nstate = {\n    "question": "What are the health benefits of yoga?",\n    "answer": None,\n    "steps": []          # you can push logs or intermediate data here\n}\n```\n\n### b. `Node`\nA callable that receives the current `state` and returns an updated `state`.  \nYou can wrap any LangChain component with `GraphNode.from_chain(chain)` or write a plain Python function:\n\n```python\ndef retrieve_documents(state):\n    docs = retriever.invoke(state["question"])\n    state["docs"] = docs\n    return state\n```\n\n### c. `Edge`\nDefines **where** execution goes next. Edges can be:\n\n* **Unconditional** – always follow to the next node.\n* **Conditional** – a lambda that inspects `state` and returns the name of the next node.\n* **Parallel** – a list of node names to run concurrently, then merge back.\n\n### d. `Graph`\nA collection of nodes + edges + a start node. Execution is driven by the `Graph.run(state)` method, which walks the graph until it reaches a terminal node or a user‑defined stop condition.\n\n---\n\n## 2. Minimal Example\n\n```python\nfrom langgraph.graph import Graph, GraphNode\nfrom langchain.chains import LLMChain\nfrom langchain.prompts import PromptTemplate\nfrom langchain.llms import OpenAI\n\n# 1️⃣ Define LLM‑driven chain (a LangChain component)\nprompt = PromptTemplate(\n    input_variables=["question", "context"],\n    template="Answer the question based only on the following context:\\n\\n{context}\\n\\nQuestion: {question}"\n)\nanswer_chain = LLMChain(llm=OpenAI(), prompt=prompt)\n\n# 2️⃣ Wrap it as a GraphNode\nanswer_node = GraphNode.from_chain(answer_chain, name="answer")\n\n# 3️⃣ Simple Python function node for retrieval\ndef retrieve(state):\n    # Pretend we have a vector store called `vector`\n    docs = vector.similarity_search(state["question"], k=3)\n    state["context"] = "\\n\\n".join([d.page_content for d in docs])\n    return state\n\nretrieve_node = GraphNode.from_callable(retrieve, name="retrieve")\n\n# 4️⃣ Build the graph\ngraph = Graph(start_node="retrieve")\ngraph.add_node(retrieve_node)\ngraph.add_node(answer_node)\n\n# Edge: after retrieval → an ...

# %%
graph.invoke({"messages":"What is Langchain?"})
# Out:
# ---CALL AGENT---
# ---CHECK RELEVANCE---
# ---DECISION: DOCS NOT RELEVANT---
# no
# ---TRANSFORM QUERY---
# ---CALL AGENT---
# {'messages': [HumanMessage(content='What is Langchain?', additional_kwargs={}, response_metadata={}, id='b6f87dc7-2de4-458d-a9f9-9f4170d9d284'),
#   AIMessage(content='', additional_kwargs={'reasoning_content': "We need to answer what is Langchain. Provide explanation. Could also cite sources. Use function to retrieve info. Let's search.", 'tool_calls': [{'id': 'fc_df5c0075-671f-4ca8-98d9-44376be29f90', 'function': {'arguments': '{"query":"What is Langchain"}', 'name': 'retriever_vector_langchain_blog'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 173, 'total_tokens': 235, 'completion_time': 0.134860483, 'completion_tokens_details': {'reasoning_tokens': 27}, 'prompt_time': 0.04250016, 'prompt_tokens_details': None, 'queue_time': 0.274123129, 'total_time': 0.177360643}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_c800245357', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019db683-c38a-7e03-8572-b189a8363343-0', tool_calls=[{'name': 'retriever_vector_langchain_blog', 'args': {'query': 'What is Langchain'}, 'id': 'fc_df5c0075-671f-4ca8-98d9-44376be29f90', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 173, 'output_tokens': 62, 'total_tokens': 235, 'output_token_details': {'reasoning': 27}}),
#   ToolMessage(content='Redirecting...\n\n\n\n\n\n\nRedirecting...\n\nRedirecting...\n\n\n\n\n\n\nRedirecting...\n\nRedirecting...\n\n\n\n\n\n\nRedirecting...', name='retriever_vector_langchain_blog', id='2af33a81-5f1b-4e94-85c3-85ac2dd0a41d', tool_call_id='fc_df5c0075-671f-4ca8-98d9-44376be29f90'),
#   AIMessage(content='**Improved question**\n\n> *Can you explain what LangChain is, describing its purpose, main components, and typical use cases for building applications that integrate large language models?*', additional_kwargs={'reasoning_content': 'The user asks: "Look at the input and try to reason about the underlying semantic intent / meaning. Here is the initial question: What is Langchain? Formulate an improved question:" So they want to produce an improved version of the question, perhaps more specific, contextual. Need to output an improved question. Should consider possible intents: they want definition, usage, benefits, architecture, examples. So improved question could be: "Can you explain what LangChain is, including its purpose, core components, and typical use cases in building LLM-powered applications?" Provide that.'}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 117, 'total_tokens': 279, 'completion_time': 0.341950757, 'completion_tokens_details': {'reasoning_tokens': 117}, 'prompt_time': 0.004370641, 'prompt_tokens_details': None, 'queue_time': 0.599248857, 'total_time': 0.346321398}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_46d8af1c62', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019db683-d54f-7ea3-949a-0000fe7505a2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 117, 'output_tokens': 162, 'total_tokens': 279, 'output_token_details': {'reasoning': 117}}),
#   AIMessage(content='**LangChain** is an open‑source framework that makes it easier to build **applications powered by large language models (LLMs)**—such as ChatGPT, Claude, Gemini, Llama, etc.—by providing reusable building blocks, abstractions, and integrations.  \nIt is not a model itself; rather, it is a **toolkit for orchestrating** LLMs with other data sources, APIs, and logic so you can create sophisticated, “thinking” applications (agents, chat‑bots, retrieval‑augmented generation, data pipelines, etc.) without having to reinvent the plumbing each time.\n\n---\n\n## Why LangChain Exists\n\n| Challenge | How LangChain Helps |\n|-----------|----------------------|\n| **Prompt engineering** – writing, templating, and managing prompts for different tasks. | PromptTemplate, FewShotPromptTemplate, ChatPromptTemplate, etc. |\n| **Connecting LLMs to external data** – knowledge bases, APIs, databases, files. | Retrievers, VectorStores, DocumentLoaders, Tools. |\n| **Stateful, multi‑step reasoning** – chaining calls, handling loops, branching logic. | Chains, SequentialChain, RouterChain, AgentExecutor. |\n| **Choosing among many LLM providers** – OpenAI, Anthropic, Cohere, Azure, HuggingFace, local models. | LLM abstraction layer (`OpenAI`, `Anthropic`, `ChatOpenAI`, `LLamaCPP`, etc.). |\n| **Deploying and scaling** – caching, streaming, async calls, tracing. | Callbacks, LangSmith (observability), caching, async APIs. |\n| **Rapid prototyping** – reusable components, examples, templates. | LangChain Hub (community‑shared chains, prompts, agents). |\n\n---\n\n## Core Concepts & Components\n\n| Component | What It Is | Typical Use |\n|-----------|------------|-------------|\n| **LLM / ChatModel** | Wrapper around a language model API (text‑completion or chat). | `OpenAI(model="gpt-4")`, `ChatAnthropic()`. |\n| **PromptTemplate** | Structured string with placeholders that are filled at runtime. | `PromptTemplate("Summarize: {text}")`. |\n| **Document & DocumentLoader** | Unified representation of a piece of text + metadata; loaders fetch from PDFs, web pages, DBs, etc. | `WebBaseLoader(url)`, `CSVLoader(path)`. |\n| **VectorStore & Retriever** | Stores embeddings for similarity search; retriever fetches relevant docs for a query. | `FAISS`, `Pinecone`, `Chroma`, `Milvus`. |\n| **Chain** | A sequence (or graph) of operations where the output of one step becomes the input to the next. | `LLMChain(prompt=..., llm=...)`, `SequentialChain([chain1, chain2])`. |\n| **Agent** | An LLM that can decide which **Tool** to call (search, calculator, API) and iterate until a final answer is produced. | `AgentExecutor(tools=[search_tool, calculator], llm=...)`. |\n| **Tool** | A callable function (often wrapped with a description) that an agent can invoke. | `SerpAPI`, `PythonREPL`, `SQLDatabaseTool`. |\n| **Memory** | Persists context across turns in a conversation (e.g., chat history, summary memory). | `ConversationBufferMemory`, `ConversationSummaryMemory`. |\n| **Callbacks / LangSmith** | Hooks for logging, tracing, debugging, and evaluating runs. | Observe token usage, latency, errors. |\n| **LangChain Hub** | Community‑curated repository of prompts, chains, agents, and integrations. | Reuse a “question‑answering over PDF” chain with a single import. |\n\n---\n\n## Typical Use‑Case Patterns\n\n| Pattern | Description | Example Stack |\n|---------|-------------|---------------|\n| **Retrieval‑Augmented Generation (RAG)** | Retrieve relevant documents → feed them to LLM → generate answer. | `DocumentLoader → EmbeddingModel → VectorStore → Retriever → LLMChain (prompt: "Answer using these docs")`. |\n| **Chatbot with Tools** | LLM decides when to call external APIs (search, calculator, calendar) to answer. | `ChatOpenAI → AgentExecutor(tools=[SearchTool, Calculator])`. |\n| **Data Extraction / Structured Output** | Prompt LLM to output JSON/CSV; validate and post‑process. | `LLMChain(prompt=ExtractionPrompt) → OutputParser(JSON)`. |\n| **Wor ...

# %%
graph.invoke({"messages":"What is Machine learning?"})
# Out:
# ---CALL AGENT---
# {'messages': [HumanMessage(content='What is Machine learning?', additional_kwargs={}, response_metadata={}, id='24001165-e1fe-4c7c-9baf-c831a1f623c8'),
#   AIMessage(content="**Machine learning (ML)** is a sub‑field of artificial intelligence (AI) that focuses on building systems that can **learn from data** and improve their performance on a task without being explicitly programmed for every possible scenario.\n\n---\n\n## Core Idea\n- **Traditional programming:** You write explicit rules (if‑else, loops) that tell a computer exactly what to do.\n- **Machine learning:** You provide the computer with **data** and a **goal** (e.g., predict a label, generate text). The algorithm automatically discovers patterns and creates a **model** that can make predictions or decisions on new, unseen data.\n\n---\n\n## Typical Workflow\n\n| Step | What Happens | Common Tools / Techniques |\n|------|--------------|---------------------------|\n| 1️⃣ **Problem Definition** | Identify the task (classification, regression, clustering, recommendation, etc.) | Business analysis, domain expertise |\n| 2️⃣ **Data Collection** | Gather raw data from databases, APIs, sensors, web scraping, etc. | SQL, pandas, APIs |\n| 3️⃣ **Data Preparation** | Clean, normalize, handle missing values, feature engineering | pandas, scikit‑learn pipelines |\n| 4️⃣ **Model Selection** | Choose a learning algorithm appropriate for the task & data size | Linear/logistic regression, decision trees, neural nets, SVMs, etc. |\n| 5️⃣ **Training** | Feed the training data to the algorithm; it adjusts internal parameters to minimize a loss function. | Gradient descent, back‑propagation |\n| 6️⃣ **Evaluation** | Measure performance on a hold‑out set (validation/test) using metrics like accuracy, F1, RMSE. | cross‑validation, ROC‑AUC |\n| 7️⃣ **Tuning & Optimization** | Adjust hyper‑parameters, try different features, ensembles. | Grid search, Bayesian optimization, AutoML |\n| 8️⃣ **Deployment** | Serve the model in production (REST API, edge device, batch jobs). | Docker, TensorFlow Serving, FastAPI, AWS SageMaker |\n| 9️⃣ **Monitoring & Maintenance** | Track drift, retrain when performance degrades. | MLflow, Prometheus, data pipelines |\n\n---\n\n## Main Categories of Machine Learning\n\n| Category | Goal | Typical Algorithms | Example Applications |\n|----------|------|--------------------|----------------------|\n| **Supervised Learning** | Learn a mapping from inputs **x** to known outputs **y**. | Linear regression, logistic regression, decision trees, random forests, gradient boosting, SVM, neural networks | Spam detection, house‑price prediction, image classification |\n| **Unsupervised Learning** | Discover hidden structure in data without explicit labels. | k‑means, hierarchical clustering, DBSCAN, PCA, autoencoders, t‑SNE | Customer segmentation, anomaly detection, dimensionality reduction |\n| **Semi‑Supervised Learning** | Combine a small labeled set with a large unlabeled set. | Self‑training, graph‑based methods, consistency regularization | Medical image labeling, language model fine‑tuning |\n| **Reinforcement Learning (RL)** | Learn to act by interacting with an environment and receiving rewards. | Q‑learning, policy gradients, DQN, PPO, AlphaZero | Game playing (Go, Chess), robotics, recommendation policies |\n| **Self‑Supervised / Foundation Models** | Create a pretext task from raw data (e.g., mask‑prediction) to learn generic representations. | Transformers (BERT, GPT, CLIP), contrastive learning (SimCLR) | Large language models, vision‑language models, speech recognition |\n\n---\n\n## Key Concepts & Terminology\n\n- **Model:** The mathematical representation (e.g., a set of weights in a neural network) that maps inputs to outputs.\n- **Training Data:** Labeled (or unlabeled) examples used to fit the model.\n- **Loss / Cost Function:** Quantifies how far predictions are from true values; the model tries to minimize it.\n- **Optimization Algorithm:** Procedure (often gradient descent) that updates model parameters to reduce loss.\n- **Overfitting vs. Underfitting:** Overfitting = model memorizes training da ...
