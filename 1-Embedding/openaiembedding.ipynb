# %% [markdown]
# ### Open AI Embeddings

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENROUTER_API_KEY"]=os.getenv("OPENROUTER_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="nvidia/llama-nemotron-embed-vl-1b-v2",
    openai_api_key=os.getenv("OPENAI_API_KEY"),
    openai_api_base="https://openrouter.ai/api/v1"
)

single_text = "Langchain and RAG are amazing frameworks and projects to work on"

single_embeddings = embeddings.embed_query(single_text)

print(len(single_embeddings))
print(single_embeddings[:10])   # print first 10 values
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[14], line 3
#       1 from langchain_openai import OpenAIEmbeddings
# ----> 3 embeddings = OpenAIEmbeddings(
#       4     model="nvidia/llama-nemotron-embed-vl-1b-v2",
#       5     openai_api_key=os.getenv("OPENAI_API_KEY"),
#       6     openai_api_base="https://openrouter.ai/api/v1"
#       7 )
#       9 single_text = "Langchain and RAG are amazing frameworks and projects to work on"
#      11 single_embeddings = embeddings.embed_query(single_text)
#
#     [... skipping hidden 1 frame]
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:448, in OpenAIEmbeddings.validate_environment(self)
#     443         self.http_async_client = httpx.AsyncClient(proxy=self.openai_proxy)
#     444     async_specific = {
#     445         "http_client": self.http_async_client,
#     446         "api_key": async_api_key_value,
#     447     }
# --> 448     self.async_client = openai.AsyncOpenAI(
#     449         **client_params,
#     450         **async_specific,  # type: ignore[arg-type]
#     451     ).embeddings
#     452 return self
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\openai\_client.py:496, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     494     api_key = os.environ.get("OPENAI_API_KEY")
#     495 if api_key is None:
# --> 496     raise OpenAIError(
#     497         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     498     )
#     499 if callable(api_key):
#     500     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x000001D138B66BA0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x000001D138B674D0>, model='nvidia/llama-nemotron-embed-vl-1b-v2:free', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base='https://openrouter.ai/api/v1', openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
## Single text embeddings
single_text="Langchain and Rag are amazing frameworks and projects to work on"
single_embeddings=embeddings.embed_query(single_text)
print(len(single_embeddings))
print(single_embeddings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 ## Single text embeddings
#       2 single_text="Langchain and Rag are amazing frameworks and projects to work on"
# ----> 3 single_embeddings=embeddings.embed_query(single_text)
#       4 print(len(single_embeddings))
#       5 print(single_embeddings)
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:801, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     791 """Call out to OpenAI's embedding endpoint for embedding query text.
#     792
#     793 Args:
#    (...)    798     Embedding for the text.
#     799 """
#     800 self._ensure_sync_client_available()
# --> 801 return self.embed_documents([text], **kwargs)[0]
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:751, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     748 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     749 # This could be optimized to avoid double work when all texts are short enough.
#     750 engine = cast(str, self.deployment)
# --> 751 return self._get_len_safe_embeddings(
#     752     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     753 )
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:618, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     616 # Make API call with this batch
#     617 batch_tokens = tokens[i:batch_end]
# --> 618 response = self.client.create(input=batch_tokens, **client_kwargs)
#     619 if not isinstance(response, dict):
#     620     response = response.model_dump()
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\openai\_base_client.py:1075, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
# -> 1075 return self._process_response(
#    1076     cast_to=cast_to,
#    1077     options=options,
#    1078     response=response,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081     retries_taken=retries_taken,
#    1082 )
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\openai\_base_client.py:1164, in SyncAPIClient._process_response(self, cast_to, options, response, stream, stream_cls, retries_taken)
#    1161 if bool(response.request.headers.get(RAW_RESPONSE_HEADER)):
#    1162     return cast(ResponseT, api_response)
# -> 1164 return api_response.parse()
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\openai\_response.py:328, in APIResponse.parse(self, to)
#     326 parsed = self._parse(to=to)
#     327 if is_given(self._options.post_parser):
# --> 328     parsed = self._options.post_parser(parsed)
#     330 if isinstance(parsed, BaseModel):
#     331     add_request_id(parsed, self.request_id)
#
# File c:\D_Drive\RAGUdemy\.venv\Lib\site-packages\openai\resources\embeddings.py:116, in Embeddings.create.<locals>.parser(obj)
#     113     return obj
#     115 if not obj.data:
# --> 116     raise ValueError("No embedding data received")
#     118 for embedding in obj.data:
#     119     data = cast(object, embedding.embedding)
#
# ValueError: No embedding data received
